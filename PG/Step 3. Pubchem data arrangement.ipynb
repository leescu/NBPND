# %%
#Import packages

#Rdkit
from rdkit import Chem

#Pandas
import pandas as pd
from pandas import DataFrame

#Others
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

import joblib
import random
import numpy as np
import os
import math
import warnings

import pandas as pd
import numpy as np
#import seaborn as sns
#import matplotlib.pyplot as plt
#from plotnine import *

# %%
def print_RxC(dataframe):
    rows= dataframe.shape[0]
    columns= dataframe.shape[1]
    rows_columns=print(dataframe.shape[0],"Moleculars ×",dataframe.shape[1],"Descriptors")
    return rows_columns
def trimm_correlated(df_in, threshold):
    df_corr = df_in.corr(method='spearman')
    df_not_correlated = ~(df_corr.mask(np.tril(np.ones([len(df_corr)]*2, dtype=bool))).abs() > threshold).any()
    un_corr_idx = df_not_correlated.loc[df_not_correlated[df_not_correlated.index] == True].index
    df_out = df_in[un_corr_idx]
    return df_out

# %%
#Setting the Work Path
warnings.filterwarnings ('ignore')
#Work Path
os.chdir("C:\\Users\\A\\Desktop\\Bioactive\\PG")

# %%
#AlvaDesc
from alvadesccliwrapper.alvadesc import AlvaDesc
#AlvaDesc Path(Linux default alvaDescCLI location)
aDesc = AlvaDesc('E:\\C++\\alvaDesc\\alvaDescCLI.exe')

# %%
Pubchem_data=pd.read_csv("./Pubchem_data.csv",sep=',')
Iso_smiles=Pubchem_data['Iso_smiles']
print_RxC(Pubchem_data)
Pubchem_data.head()
# Out:
# 11406 Moleculars × 3 Descriptors
#      cid                                         Iso_smiles       Type
# 0   5273                   C1CC(OC1)[N+]2=CNC3=C(N=CN=C32)N  Adenosine
# 1  13463         C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)CCl)O)O)N  Adenosine
# 2  39148    CN(C)C1[C@H](O[C@H](C1O)N2C=NC3=C(N=CN=C32)N)CO  Adenosine
# 3  56328         C1[C@H](O[C@H](C1F)N2C=NC3=C(N=CN=C32)N)CO  Adenosine
# 4  67358  C1=NC(=C2C(=N1)N(C=[N+]2[O-])[C@H]3[C@@H]([C@@...  Adenosine

# %%
Smis=[]
for i in Iso_smiles:
    Smis.append(i)
Mols = []
for Smi in Smis:
    Mol = Chem.MolFromSmiles(Smi)
    Mols.append(Mol)
Canonical_smis = []
for Mol in Mols:
    Canonical_smi = Chem.MolToSmiles(Mol)
    Canonical_smis.append(Canonical_smi)
Pubchem_data['Canonical_smiles']=Canonical_smis

# %%
#Load the data
Raw_data= pd.read_csv('./Raw_data.csv',index_col=0)
X_scaled_data= pd.read_csv('./X_scaled_data.csv',index_col=0)
Transformer= joblib.load(filename='./Scaler_transformer.pkl')

# %%
Pubchem_data
# Out:
#              cid                                         Iso_smiles  \
# 0           5273                   C1CC(OC1)[N+]2=CNC3=C(N=CN=C32)N
# 1          13463         C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)CCl)O)O)N
# 2          39148    CN(C)C1[C@H](O[C@H](C1O)N2C=NC3=C(N=CN=C32)N)CO
# 3          56328         C1[C@H](O[C@H](C1F)N2C=NC3=C(N=CN=C32)N)CO
# 4          67358  C1=NC(=C2C(=N1)N(C=[N+]2[O-])[C@H]3[C@@H]([C@@...
# ...          ...                                                ...
# 11343  121487078        C1[C@@H](O[C@@H](C1CCC#N)CO)N2C=CC(=O)NC2=O
# 11346  121487098  C1=CN(C(=O)NC1=O)[C@H]2C(C([C@H](O2)CO)F)[N+]3...
# 11354  121487432  CC1=CN(C(=O)NC1=O)[C@H]2[C@@H]([C@H]([C@H](O2)...
# 11372    6482243  C1=C(C(=O)NC(=O)N1[C@H]2[C@@H]([C@@H]([C@H](O2...
# 11400   12313774         C1=C(N(C(=O)NC1=O)C2C(C(C(O2)CO)O)O)C(=O)O
#
#             Type                                   Canonical_smiles
# 0      Adenosine                        Nc1ncnc2c1[nH]c[n+]2C1CCCO1
# 1      Adenosine                     Nc1ncnc2c1ncn2C1OC(CCl)C(O)C1O
# 2      Adenosine       CN(C)C1C(O)[C@H](n2cnc3c(N)ncnc32)O[C@@H]1CO
# 3      Adenosine                Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO)CC1F
# 4      Adenosine  Nc1ncnc2c1[n+]([O-])cn2[C@@H]1O[C@H](CO)[C@@H]...
# ...          ...                                                ...
# 11343    Uridine         N#CCCC1C[C@H](n2ccc(=O)[nH]c2=O)O[C@@H]1CO
# 11346    Uridine  O=c1ccn([C@@H]2O[C@H](CO)C(F)C2[n+]2cc[nH]c2)c...
# 11354    Uridine  Cc1cn([C@@H]2O[C@H](CO)[C@H](C(F)(F)F)[C@H]2O)...
# 11372    Uridine  O=c1[nH]c(=O)n([C@@H]2O[C@H](CO)[C@@H](O)[C@H]...
# 11400    Uridine           O=C(O)c1cc(=O)[nH]c(=O)n1C1OC(CO)C(O)C1O
#
# [7287 rows x 4 columns]

# %%
Raw_data
# Out:
#            acvalue      aid        sid      cid.1  geneid        pmid  \
# cid
# 5904          0.29  1437928  103165163       5904     NaN  28079378.0
# 155543311     2.30  1571234  440163866  155543311     NaN  30881614.0
# 155511868     2.40  1571234  440111790  155511868     NaN  30881614.0
# 155547676     3.70  1571234  440174844  155547676     NaN  30881614.0
# 155510814     4.30  1571234  440110233  155510814     NaN  30881614.0
# ...            ...      ...        ...        ...     ...         ...
# 162658036      NaN  1725206  461535923  162658036     NaN  33062172.0
# 162647428      NaN  1725205  461520763  162647428     NaN  33062172.0
# 162663043      NaN  1725205  461543092  162663043     NaN  33062172.0
# 168292812      NaN  1848340  482079746  168292812     NaN  36273428.0
# 168275423      NaN  1848361  482055793  168275423     NaN  36273428.0
#
#                       aidtype  aidmdate  hasdrc  rnai  ...      targeturl  \
# cid                                                    ...
# 5904             Confirmatory  20220830       0     0  ...  /taxonomy/837
# 155543311        Confirmatory  20220830       0     0  ...  /taxonomy/837
# 155511868        Confirmatory  20220830       0     0  ...  /taxonomy/837
# 155547676        Confirmatory  20220830       0     0  ...  /taxonomy/837
# 155510814        Confirmatory  20220830       0     0  ...  /taxonomy/837
# ...                       ...       ...     ...   ...  ...            ...
# 162658036  Literature-derived  20220318       0     0  ...  /taxonomy/837
# 162647428  Literature-derived  20220318       0     0  ...  /taxonomy/837
# 162663043  Literature-derived  20220318       0     0  ...  /taxonomy/837
# 168292812  Literature-derived  20230629       0     0  ...  /taxonomy/837
# 168275423  Literature-derived  20230629       0     0  ...  /taxonomy/837
#
#            ecs repacxn taxid cellids targettaxid tissueid tissuename  \
# cid
# 5904       NaN     NaN   NaN     NaN         837      NaN        NaN
# 155543311  NaN     NaN   NaN     NaN         837      NaN        NaN
# 155511868  NaN     NaN   NaN     NaN         837      NaN        NaN
# 155547676  NaN     NaN   NaN     NaN         837      NaN        NaN
# 155510814  NaN     NaN   NaN     NaN         837      NaN        NaN
# ...        ...     ...   ...     ...         ...      ...        ...
# 162658036  NaN     NaN   NaN     NaN         837      NaN        NaN
# 162647428  NaN     NaN   NaN     NaN         837      NaN        NaN
# 162663043  NaN     NaN   NaN     NaN         837      NaN        NaN
# 168292812  NaN     NaN   NaN     NaN         837      NaN        NaN
# 168275423  NaN     NaN   NaN     NaN         837      NaN        NaN
#
#           Antimicrobial                                             SMILES
# cid
# 5904                  1    CC1(C(N2C(S1)C(C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C
# 155543311             1  C1=CC(=CC=C1C2=NC(=C(O2)C3=CC=C(C=C3)F)C4=CC=C...
# 155511868             1  C1=CC=C(C(=C1)C2=NC(=C(O2)C3=CC=CO3)C4=CC=CO4)...
# 155547676             1  CCN(CC)C1=NC(=NC(=N1)C2=CN(N=N2)C3=CC=C(C=C3)C...
# 155510814             1  C1=CC=C(C=C1)C2=C(OC(=N2)C3=CC(=CC=C3)N4C=C(N=...
# ...                 ...                                                ...
# 162658036             1  CN1C=C(C2=C1C=CC(=C2)[N+](=O)[O-])CC3=CC(=C(C=...
# 162647428             0  CN1C=C(C2=CC=CC=C21)CC3=CC(=C(C=C3)OC)C(=O)NS(...
# 162663043             0  CN1C=C(C2=CC=CC=C21)CC3=CC(=C(C=C3)OC)C(=O)NS(...
# 168292812             1  CN1C=C(C2=C1C=CC(=C2)[N+](=O)[O-])CC3=CC(=C(C=...
# 168275423             1  CN1C=C(C2=C1C=CC(=C2)[N+](=O)[O-])CC3=CC(=C(C=...
#
# [152 rows x 28 columns]

# %%
Pubchem_data=Pubchem_data.drop_duplicates(subset="cid")
Pubchem_data=Pubchem_data.drop_duplicates(subset="Canonical_smiles")
Pubchem_data=Pubchem_data[~ Pubchem_data['Canonical_smiles'].isin(Raw_data['SMILES'])]
Pubchem_data.index=Pubchem_data['cid']
Pubchem_data.drop('cid',axis = 1,inplace = True)
print_RxC(Pubchem_data)
Pubchem_data.to_csv("./Pubchem_data_clearn.csv",sep=',',header=1,index=1)
Pubchem_data.head()
# Out:
# 7287 Moleculars × 3 Descriptors
#                                               Iso_smiles       Type  \
# cid
# 5273                    C1CC(OC1)[N+]2=CNC3=C(N=CN=C32)N  Adenosine
# 13463         C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)CCl)O)O)N  Adenosine
# 39148    CN(C)C1[C@H](O[C@H](C1O)N2C=NC3=C(N=CN=C32)N)CO  Adenosine
# 56328         C1[C@H](O[C@H](C1F)N2C=NC3=C(N=CN=C32)N)CO  Adenosine
# 67358  C1=NC(=C2C(=N1)N(C=[N+]2[O-])[C@H]3[C@@H]([C@@...  Adenosine
#
#                                         Canonical_smiles
# cid
# 5273                         Nc1ncnc2c1[nH]c[n+]2C1CCCO1
# 13463                     Nc1ncnc2c1ncn2C1OC(CCl)C(O)C1O
# 39148       CN(C)C1C(O)[C@H](n2cnc3c(N)ncnc32)O[C@@H]1CO
# 56328                Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO)CC1F
# 67358  Nc1ncnc2c1[n+]([O-])cn2[C@@H]1O[C@H](CO)[C@@H]...

# %%
X_scaled_data
# Out:
#              GATS4s  ChiA_B(s)    GATS2v  phLevel2  ChiA_B(e)       AMW  \
# cid
# 5904       0.356299   0.375195  0.315005  0.555556   0.264016  0.570036
# 155543311  0.282367   0.181396  0.358639  0.000000   0.071852  0.816787
# 155511868  0.286275   0.189276  0.332109  0.000000   0.069679  0.816025
# 155547676  0.528336   0.369634  0.071157  0.000000   0.230348  0.598032
# 155510814  0.291741   0.237414  0.374375  0.000000   0.102368  0.713478
# ...             ...        ...       ...       ...        ...       ...
# 162658036  0.324919   0.107418  0.083200  0.000000   0.000000  0.795245
# 162647428  0.304750   0.226692  0.089359  0.000000   0.102793  0.652225
# 162663043  0.301097   0.226692  0.089359  0.000000   0.102793  0.652225
# 168292812  0.302748   0.178808  0.000000  0.000000   0.048762  1.000000
# 168275423  0.288379   0.164501  0.026426  0.000000   0.045597  0.825962
#
#            s3_relPathLength_2  s3_phRelSize_2  s3_phRelSize  \
# cid
# 5904                 0.448148        0.456944      0.362319
# 155543311            0.000000        0.000000      0.000000
# 155511868            0.000000        0.000000      0.000000
# 155547676            0.000000        0.000000      0.000000
# 155510814            0.000000        0.000000      0.000000
# ...                       ...             ...           ...
# 162658036            0.000000        0.000000      0.000000
# 162647428            0.000000        0.000000      0.000000
# 162663043            0.000000        0.000000      0.000000
# 168292812            0.000000        0.000000      0.000000
# 168275423            0.000000        0.000000      0.000000
#
#            s4_relPathLength_2  ...  F01[C-F]  F03[C-F]        nF  F01[C-C]  \
# cid                            ...
# 5904                 0.593056  ...  0.000000  0.000000  0.000000  0.161290
# 155543311            0.000000  ...  0.666667  0.666667  0.666667  0.516129
# 155511868            0.000000  ...  0.333333  0.333333  0.333333  0.419355
# 155547676            0.000000  ...  0.000000  0.000000  0.000000  0.387097
# 155510814            0.000000  ...  0.333333  0.333333  0.333333  0.516129
# ...                       ...  ...       ...       ...       ...       ...
# 162658036            0.000000  ...  0.000000  0.000000  0.000000  0.306452
# 162647428            0.000000  ...  0.166667  0.166667  0.166667  0.306452
# 162663043            0.000000  ...  0.166667  0.166667  0.166667  0.306452
# 168292812            0.000000  ...  0.000000  0.000000  0.000000  0.306452
# 168275423            0.000000  ...  0.000000  0.000000  0.000000  0.306452
#
#                 NsF  P_VSA_e_6  SpDiam_Dz(p)  F07[C-N]  SpMax7_Bh(p)  \
# cid
# 5904       0.000000   0.000000      0.037905  0.032787      0.596202
# 155543311  0.666667   0.666667      0.179897  0.442623      0.912792
# 155511868  0.333333   0.333333      0.146283  0.524590      0.879333
# 155547676  0.000000   0.000000      0.139458  0.377049      0.902424
# 155510814  0.333333   0.333333      0.159631  0.459016      0.910879
# ...             ...        ...           ...       ...           ...
# 162658036  0.000000   0.000000      0.078985  0.114754      0.733631
# 162647428  0.166667   0.166667      0.055872  0.065574      0.722804
# 162663043  0.166667   0.166667      0.056407  0.065574      0.722769
# 168292812  0.000000   0.000000      0.066177  0.098361      0.723361
# 168275423  0.000000   0.000000      0.066305  0.098361      0.723027
#
#            SpMAD_B(s)
# cid
# 5904         0.714129
# 155543311    0.589762
# 155511868    0.415154
# 155547676    0.154898
# 155510814    0.402707
# ...               ...
# 162658036    0.928131
# 162647428    0.705905
# 162663043    0.705951
# 168292812    0.725923
# 168275423    0.748889
#
# [152 rows x 1503 columns]

# %%
Canonical_smis=Pubchem_data['Canonical_smiles']

# %%
#Calculate the descriotors
aDesc.set_input_SMILES(Canonical_smis.tolist())
if not aDesc.calculate_descriptors('ALL'):
 print('Error: ' + aDesc.get_error())
else:
 Data_all=aDesc.get_output()

# %%
Data_all=pd.DataFrame(Data_all)
Desc_names_names=aDesc.get_output_descriptors()
Data_all.columns=Desc_names_names
Data_all.index=Pubchem_data.index

# %%
X_test=Data_all[X_scaled_data.columns]
X_test.head()
# Out:
#          GATS4s  ChiA_B(s)    GATS2v  phLevel2  ChiA_B(e)       AMW  \
# cid
# 5273   0.978396   0.211957  0.917750      0.00   0.268048  7.639259
# 13463  1.091301   0.202421  0.917643      1.75   0.265464  9.216774
# 39148  0.829656   0.206499  0.764876      2.00   0.267529  7.547692
# 56328  0.965898   0.203841  0.905895      1.00   0.266526  8.442333
# 67358  0.888087   0.198292  0.929044      2.00   0.263532  8.584242
#
#        s3_relPathLength_2  s3_phRelSize_2  s3_phRelSize  s4_relPathLength_2  \
# cid
# 5273             1.000000        0.500000      0.066667            0.500000
# 13463            0.762500        0.362500      0.078947            0.530449
# 39148            0.622024        0.363095      0.095238            0.530449
# 56328            1.000000        0.250000      0.055556            0.527778
# 67358            0.762500        0.475000      0.100000            0.488636
#
#        ...  F01[C-F]  F03[C-F]   nF  F01[C-C]  NsF  P_VSA_e_6  SpDiam_Dz(p)  \
# cid    ...
# 5273   ...       0.0       0.0  0.0       5.0  0.0   0.000000     85.820501
# 13463  ...       0.0       0.0  0.0       6.0  0.0   0.000000    139.609756
# 39148  ...       0.0       0.0  0.0       6.0  0.0   0.000000    165.110091
# 56328  ...       1.0       1.0  1.0       6.0  1.0  14.960113    136.670054
# 67358  ...       0.0       0.0  0.0       6.0  0.0   0.000000    158.012165
#
#        F07[C-N]  SpMax7_Bh(p)  SpMAD_B(s)
# cid
# 5273        4.0      2.156296    1.686640
# 13463       4.0      2.135342    1.923335
# 39148      10.0      2.617895    1.829041
# 56328       4.0      2.132923    1.997764
# 67358       4.0      2.160298    2.133529
#
# [5 rows x 1503 columns]

# %%
X_test_scaled=Transformer.transform(X_test)
X_test_scaled =pd.DataFrame(X_test_scaled)
X_test_scaled.columns=X_test.columns
X_test_scaled.index=X_test.index
X_test_scaled.to_csv("./X_test_data.csv",sep=',',header=1,index=1)
print_RxC(X_test_scaled)
X_test_scaled.head()
# Out:
# 7287 Moleculars × 1503 Descriptors
#          GATS4s  ChiA_B(s)    GATS2v  phLevel2  ChiA_B(e)       AMW  \
# cid
# 5273   0.342920   0.411183  0.258906  0.000000   0.298254  0.458580
# 13463  0.417160   0.243434  0.258735  0.583333   0.247568  0.798290
# 39148  0.245117   0.315163  0.016047  0.666667   0.288068  0.438861
# 56328  0.334702   0.268416  0.240072  0.333333   0.268396  0.631518
# 67358  0.283538   0.170804  0.276847  0.666667   0.209680  0.662078
#
#        s3_relPathLength_2  s3_phRelSize_2  s3_phRelSize  s4_relPathLength_2  \
# cid
# 5273             0.733333        0.875000      0.333333            0.437500
# 13463            0.559167        0.634375      0.394737            0.464143
# 39148            0.456151        0.635417      0.476190            0.464143
# 56328            0.733333        0.437500      0.277778            0.461806
# 67358            0.559167        0.831250      0.500000            0.427557
#
#        ...  F01[C-F]  F03[C-F]        nF  F01[C-C]       NsF  P_VSA_e_6  \
# cid    ...
# 5273   ...  0.000000  0.000000  0.000000  0.016129  0.000000   0.000000
# 13463  ...  0.000000  0.000000  0.000000  0.032258  0.000000   0.000000
# 39148  ...  0.000000  0.000000  0.000000  0.032258  0.000000   0.000000
# 56328  ...  0.166667  0.083333  0.166667  0.032258  0.166667   0.166667
# 67358  ...  0.000000  0.000000  0.000000  0.032258  0.000000   0.000000
#
#        SpDiam_Dz(p)  F07[C-N]  SpMax7_Bh(p)  SpMAD_B(s)
# cid
# 5273       0.010425  0.065574      0.395884    0.192904
# 13463      0.023529  0.065574      0.387317    0.501235
# 39148      0.029742  0.163934      0.584624    0.378403
# 56328      0.022813  0.065574      0.386328    0.598190
# 67358      0.028013  0.065574      0.397521    0.775044
#
# [5 rows x 1503 columns]
